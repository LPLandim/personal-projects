# %% [markdown]
# # Checkpoint Machine Learning - Regressão Linear

# %% [markdown]
# O objetivo deste notebook é explicar o IMC (Índice de Massa Corporal) com base nos dados da planilha do PNS

# %% [markdown]
#  * As variáveis que compõem a Regressão Linear Múltipla foram escolhidas com o objetivo de maximizar o R-quadrado.
#    Isso pode envolver a experimentação com diferentes combinações de variáveis.

# %% [markdown]
# * As variáveis foram escolhidas para maximizar o R-quadrado. No entanto, um R-quadrado alto não garante um bom modelo. Provável que o modelo seja falho e não ajude a explicar, por conta da falta de informações e validação do modelo.

# %% [markdown]
# * Se as variáveis escolhidas não têm uma relação forte ou direta com o IMC, elas não ajudarão a explicar.
#
# * Não necessariamente a saúde atual da pessoa terá relação direta com o IMC.

# %% [markdown]
# * Se o modelo está sobreajustado (muitas variáveis) ou sofre de multicolinearidade (variáveis altamente correlacionadas), ele pode falhar.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv("OLS_EX2.csv", encoding= 'UTF-8', sep = ';')
df.isna().sum()
# Out:
# estado                   0
# total_moradores        246
# tipo_local               0
# num_comodos            246
# problemas_recentes     246
# saude                    0
# peso                  3661
# altura                3770
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#                   estado  total_moradores tipo_local  num_comodos  \
# 0                Alagoas              1.0     Urbano          3.0
# 1     Mato Grosso do Sul              3.0     Urbano          6.0
# 6         Rio de Janeiro              2.0     Urbano          5.0
# 8             Pernambuco              2.0     Urbano          7.0
# 17            Pernambuco              3.0     Urbano          8.0
# ...                  ...              ...        ...          ...
# 4985   Rio Grande do Sul              1.0     Urbano          8.0
# 4987      Espírito Santo              3.0     Urbano          4.0
# 4988             Sergipe              3.0      Rural          5.0
# 4992               Piauí              3.0     Urbano          9.0
# 4993      Espírito Santo              2.0     Urbano          5.0
#
#      problemas_recentes      saude  peso  altura
# 0                   Não    Regular  58.0   164.0
# 1                   Não    Regular  71.0   159.0
# 6                   Sim       Ruim  90.0   175.0
# 8                   Não  Muito boa  79.0   172.0
# 17                  Sim    Regular  64.0   148.0
# ...                 ...        ...   ...     ...
# 4985                Não    Regular  61.0   158.0
# 4987                Não        Boa  92.0   174.0
# 4988                Não        Boa  56.0   163.0
# 4992                Não    Regular  66.5   160.0
# 4993                Não        Boa  92.0   162.0
#
# [1192 rows x 8 columns]

# %% [markdown]
# # Varíavel Label

# %%
df['IMC'] = df['peso'] / (df['altura'] / 100) ** 2
df['tipo_local'] = df.apply(lambda row: 1 if row['tipo_local'] == 'Urbano' else 0, axis = 1)
df['problemas_recentes'] = df.apply(lambda row: 1 if row['problemas_recentes'] == 'Sim' else 0, axis = 1)

df['saude'] = df['saude'].apply(lambda x: 0 if x == 'Muito ruim' 
                                 else 1 if x == 'Ruim' 
                                 else 2 if x == 'Regular' 
                                 else 3 if x == 'Boa' 
                                 else 4 if x == 'Muito boa' 
                                 else x)



df
# Out:
#                   estado  total_moradores  tipo_local  num_comodos  \
# 0                Alagoas              1.0           1          3.0
# 1     Mato Grosso do Sul              3.0           1          6.0
# 6         Rio de Janeiro              2.0           1          5.0
# 8             Pernambuco              2.0           1          7.0
# 17            Pernambuco              3.0           1          8.0
# ...                  ...              ...         ...          ...
# 4985   Rio Grande do Sul              1.0           1          8.0
# 4987      Espírito Santo              3.0           1          4.0
# 4988             Sergipe              3.0           0          5.0
# 4992               Piauí              3.0           1          9.0
# 4993      Espírito Santo              2.0           1          5.0
#
#       problemas_recentes  saude  peso  altura        IMC
# 0                      0      2  58.0   164.0  21.564545
# 1                      0      2  71.0   159.0  28.084332
# 6                      1      1  90.0   175.0  29.387755
# 8                      0      4  79.0   172.0  26.703624
# 17                     1      2  64.0   148.0  29.218408
# ...                  ...    ...   ...     ...        ...
# 4985                   0      2  61.0   158.0  24.435187
# 4987                   0      3  92.0   174.0  30.387105
# 4988                   0      3  56.0   163.0  21.077195
# 4992                   0      2  66.5   160.0  25.976562
# 4993                   0      3  92.0   162.0  35.055632
#
# [1192 rows x 9 columns]

# %%
model = LinearRegression(n_jobs=None, fit_intercept=True, copy_X=True)

x = df[['total_moradores', 'tipo_local', 'num_comodos', 'problemas_recentes', 'saude']].to_numpy()
y = df['IMC'].to_numpy()

model.fit(x, y)

print('R-quadrado:', model.score(x, y))
print('Intercepto:', model.intercept_)
print(f'Coeficientes:', model.coef_, "\n\n")

x = sm.add_constant(x)
model = sm.OLS(y, x).fit()

print(model.summary())
# Out:
# R-quadrado: 0.02093094040785337
# Intercepto: 28.376828655193073
# Coeficientes: [-0.09291867  0.3082171   0.01692314  0.58805328 -0.73661622]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     5.071
# Date:                Mon, 26 Feb 2024   Prob (F-statistic):           0.000132
# Time:                        13:18:31   Log-Likelihood:                -3515.6
# No. Observations:                1192   AIC:                             7043.
# Df Residuals:                    1186   BIC:                             7074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.3768      0.679     41.804      0.000      27.045      29.709
# x1            -0.0929      0.090     -1.038      0.299      -0.269       0.083
# x2             0.3082      0.339      0.910      0.363      -0.356       0.973
# x3             0.0169      0.058      0.291      0.771      -0.097       0.131
# x4             0.5881      0.490      1.201      0.230      -0.373       1.549
# x5            -0.7366      0.178     -4.142      0.000      -1.086      -0.388
# ==============================================================================
# Omnibus:                       58.321   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.869
# Skew:                           0.513   Prob(JB):                     1.11e-15
# Kurtosis:                       3.579   Cond. No.                         41.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Variável Binária - melhor r_quadrado

# %%
df['Muito_Ruim'] = df.apply(lambda row: 1 if row['saude'] == 0 else 0, axis = 1) # monday = segunda-feira
df['Ruim'] = df.apply(lambda row: 1 if row['saude'] == 1 else 0, axis = 1) # tuesday = terça-feira
df['Regular'] = df.apply(lambda row: 1 if row['saude'] == 2 else 0, axis = 1) # wednesday = quarta-feira
df['Boa'] = df.apply(lambda row: 1 if row['saude'] == 3 else 0, axis = 1) # thursday = quinta-feira
df['Muito_Boa'] = df.apply(lambda row: 1 if row['saude'] == 4 else 0, axis = 1) # friday = sextafeira

# %%
df.head()
# Out:
#                 estado  total_moradores  tipo_local  num_comodos  \
# 0              Alagoas              1.0           1          3.0
# 1   Mato Grosso do Sul              3.0           1          6.0
# 6       Rio de Janeiro              2.0           1          5.0
# 8           Pernambuco              2.0           1          7.0
# 17          Pernambuco              3.0           1          8.0
#
#     problemas_recentes  saude  peso  altura        IMC  Muito_Ruim  Ruim  \
# 0                    0      2  58.0   164.0  21.564545           0     0
# 1                    0      2  71.0   159.0  28.084332           0     0
# 6                    1      1  90.0   175.0  29.387755           0     1
# 8                    0      4  79.0   172.0  26.703624           0     0
# 17                   1      2  64.0   148.0  29.218408           0     0
#
#     Regular  Boa  Muito_Boa
# 0         1    0          0
# 1         1    0          0
# 6         0    0          0
# 8         0    0          1
# 17        1    0          0

# %%
model = LinearRegression(n_jobs=None, fit_intercept=True, copy_X=True)

x = df[['Muito_Ruim', 'Ruim', 'Regular', 'Boa', 'Muito_Boa']].to_numpy()
y = df['IMC'].to_numpy()

model.fit(x, y)

print('R-quadrado:', model.score(x, y))
print('Intercepto:', model.intercept_)
print(f'Coeficientes:', model.coef_, "\n\n")

x = sm.add_constant(x)
model = sm.OLS(y, x).fit()

print(model.summary())
# Out:
# R-quadrado: 0.025157520866534444
# Intercepto: -77388251392599.33
# Coeficientes: [7.73882514e+13 7.73882514e+13 7.73882514e+13 7.73882514e+13
#  7.73882514e+13]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     7.724
# Date:                Mon, 26 Feb 2024   Prob (F-statistic):           3.82e-06
# Time:                        13:18:31   Log-Likelihood:                -3512.9
# No. Observations:                1192   AIC:                             7036.
# Df Residuals:                    1187   BIC:                             7061.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.7302      0.251     90.539      0.000      22.238      23.223
# x1             5.4587      1.076      5.074      0.000       3.348       7.569
# x2             6.2109      0.576     10.789      0.000       5.081       7.340
# x3             4.3651      0.322     13.565      0.000       3.734       4.996
# x4             3.2503      0.294     11.061      0.000       2.674       3.827
# x5             3.4452      0.386      8.918      0.000       2.687       4.203
# ==============================================================================
# Omnibus:                       57.453   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.683
# Skew:                           0.508   Prob(JB):                     2.01e-15
# Kurtosis:                       3.574   Cond. No.                     2.15e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.6e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
