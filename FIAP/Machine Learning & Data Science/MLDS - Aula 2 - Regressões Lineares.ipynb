# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels.api as sm

df = pd.read_csv("imc.csv", sep = '\t')
df2 = pd.read_csv("runner.csv", sep = '\t')
df3 = pd.read_csv("visits.csv", sep = '\t')

# %%
df2.head(10)
# Out:
#    running_time  heartbeat
# 0         34.05        150
# 1         34.12        154
# 2         34.13        152
# 3         34.72        144
# 4         35.37        143
# 5         35.57        146
# 6         35.57        148
# 7         35.72        152
# 8         35.73        146
# 9         36.17        138

# %%
# Running 
# o meu X vai ser running time e o meu Y será o heartbeat

# Y = B0 + B1 * X1 + E

model = LinearRegression(n_jobs = None, fit_intercept = True, copy_X = True)

x = df2["running_time"].to_numpy().reshape(-1,  1)
y = df2['heartbeat'].to_numpy()
model.fit(x, y)

# intercept= b0 = alfa =  tetha0
# coef = lista com todos os betas a partir do 1;

print(model.score(x, y))
print(model.intercept_)
print(model.coef_)
# Out:
# 0.4010707292485014
# 285.60791501472215
# [-3.93871323]

# %%
# r_quadrado = 0.4

x = sm.add_constant(x)
model = sm.OLS(y, x).fit()

model.summary()
# Y = 285 - 3.9 * X
# r_quadrado 40%
# tenho significância estatística
# Out:
# e:\Python\Python3.12\Lib\site-packages\scipy\stats\_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     5.357
# Date:                Mon, 26 Feb 2024   Prob (F-statistic):             0.0493
# Time:                        13:01:56   Log-Likelihood:                -26.992
# No. Observations:                  10   AIC:                             57.98
# Df Residuals:                       8   BIC:                             58.59
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# Modelo de regressão lienar que preveja a quantidade de visitas em um dado dia

# %%
df3
# Out:
#            date  visits
# 0    2023-01-01      56
# 1    2023-01-02      52
# 2    2023-01-03      83
# 3    2023-01-04      84
# 4    2023-01-05      94
# ..          ...     ...
# 313  2023-11-10     155
# 314  2023-11-11     126
# 315  2023-11-12      67
# 316  2023-11-13     140
# 317  2023-11-14       1
#
# [318 rows x 2 columns]

# %%
df3['date'] = pd.to_datetime(df3["date"])
df3['dow'] = df3['date'].dt.dayofweek

df3['mon'] = df3.apply(lambda row: 1 if row['dow'] == 0 else 0, axis = 1) # monday = segunda-feira
df3['tue'] = df3.apply(lambda row: 1 if row['dow'] == 1 else 0, axis = 1) # tuesday = terça-feira
df3['wed'] = df3.apply(lambda row: 1 if row['dow'] == 2 else 0, axis = 1) # wednesday = quarta-feira
df3['thu'] = df3.apply(lambda row: 1 if row['dow'] == 3 else 0, axis = 1) # thursday = quinta-feira
df3['fri'] = df3.apply(lambda row: 1 if row['dow'] == 4 else 0, axis = 1) # friday = sextafeira
df3['sat'] = df3.apply(lambda row: 1 if row['dow'] == 5 else 0, axis = 1) # saturday = sábado
df3['sun'] = df3.apply(lambda row: 1 if row['dow'] == 6 else 0, axis = 1) # sunday = domingo

df3['dow']
# Out:
# 0      6
# 1      0
# 2      1
# 3      2
# 4      3
#       ..
# 313    4
# 314    5
# 315    6
# 316    0
# 317    1
# Name: dow, Length: 318, dtype: int32

# %%
df3
# Out:
#           date  visits  dow  mon  tue  wed  thu  fri  sat  sun
# 0   2023-01-01      56    6    0    0    0    0    0    0    1
# 1   2023-01-02      52    0    1    0    0    0    0    0    0
# 2   2023-01-03      83    1    0    1    0    0    0    0    0
# 3   2023-01-04      84    2    0    0    1    0    0    0    0
# 4   2023-01-05      94    3    0    0    0    1    0    0    0
# ..         ...     ...  ...  ...  ...  ...  ...  ...  ...  ...
# 313 2023-11-10     155    4    0    0    0    0    1    0    0
# 314 2023-11-11     126    5    0    0    0    0    0    1    0
# 315 2023-11-12      67    6    0    0    0    0    0    0    1
# 316 2023-11-13     140    0    1    0    0    0    0    0    0
# 317 2023-11-14       1    1    0    1    0    0    0    0    0
#
# [318 rows x 10 columns]

# %%
model = LinearRegression(n_jobs = None, fit_intercept = True, copy_X = True)

x = df3[['mon', 'tue','wed', 'thu', 'fri', 'sat', 'sun']].to_numpy()
y = df3['visits'].to_numpy()

model.fit(x, y)
print(model.score(x, y))

x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
model.summary()
# Out:
# 0.4936923199698283
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.501
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     51.99
# Date:                Mon, 26 Feb 2024   Prob (F-statistic):           3.81e-44
# Time:                        13:01:56   Log-Likelihood:                -1465.4
# No. Observations:                 318   AIC:                             2945.
# Df Residuals:                     311   BIC:                             2971.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# IMC

# %%
df
# Out:
#        imc drugs alcohol tobacco   age        sex ethnicity
# 0    26.00    no      no      no  69.0  Masculino     Parda
# 1     0.00    no      no      no  39.0  Masculino     Parda
# 2    28.00    no      no      no  73.0  Masculino    Branca
# 3    28.00    no      no      no  72.0  Masculino    Branca
# 4    39.00    no      no      no  39.0   Feminino    Branca
# ..     ...   ...     ...     ...   ...        ...       ...
# 894  20.83    no      no     yes  45.0   Feminino     Negra
# 895  35.32    no      no      no  50.0   Feminino     Parda
# 896  22.21    no      no      no  32.0   Feminino    Branca
# 897  36.98    no      no     yes  74.0   Feminino    Branca
# 898  35.05    no      no      no  42.0   Feminino    Branca
#
# [899 rows x 7 columns]

# %%
df = df.loc[df['imc'] != 0]
df = df.dropna(how= "any", axis = 0)
df
# Out:
#        imc drugs alcohol tobacco   age        sex ethnicity
# 0    26.00    no      no      no  69.0  Masculino     Parda
# 2    28.00    no      no      no  73.0  Masculino    Branca
# 3    28.00    no      no      no  72.0  Masculino    Branca
# 4    39.00    no      no      no  39.0   Feminino    Branca
# 5    24.00    no     yes     yes  66.0  Masculino    Branca
# ..     ...   ...     ...     ...   ...        ...       ...
# 894  20.83    no      no     yes  45.0   Feminino     Negra
# 895  35.32    no      no      no  50.0   Feminino     Parda
# 896  22.21    no      no      no  32.0   Feminino    Branca
# 897  36.98    no      no     yes  74.0   Feminino    Branca
# 898  35.05    no      no      no  42.0   Feminino    Branca
#
# [658 rows x 7 columns]

# %%
df['drugs'] = df.apply(lambda row: 1 if row['drugs'] == 'yes' else 0, axis= 1)
df['alcohol'] = df.apply(lambda row: 1 if row['alcohol'] == 'yes' else 0, axis= 1)
df['tobacco'] = df.apply(lambda row: 1 if row['tobacco'] == 'yes' else 0, axis= 1)
df['drogas_geral'] = df.apply(lambda row: 1 if row['tobacco'] == '1' or row == 1 else 0, axis= 1)

df['sex'] = df.apply(lambda row: 1 if row['sex'] == 'Masculino' else 0, axis= 1)
df['parda'] = df.apply(lambda row: 1 if row['ethnicity'] == 'Parda' else 0, axis= 1)
df['branca'] = df.apply(lambda row: 1 if row['ethnicity'] == 'Branca' else 0, axis= 1)
df['negra'] = df.apply(lambda row: 1 if row['ethnicity'] == 'Negra' else 0, axis= 1)
df['amarela'] = df.apply(lambda row: 1 if row['ethnicity'] == 'Amarela' else 0, axis= 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13628\1467970705.py in ?()
#       1 df['drugs'] = df.apply(lambda row: 1 if row['drugs'] == 'yes' else 0, axis= 1)
#       2 df['alcohol'] = df.apply(lambda row: 1 if row['alcohol'] == 'yes' else 0, axis= 1)
#       3 df['tobacco'] = df.apply(lambda row: 1 if row['tobacco'] == 'yes' else 0, axis= 1)
# ----> 4 df['drogas_geral'] = df.apply(lambda row: 1 if row['tobacco'] == '1' or row == 1 else 0, axis= 1)
#       5
#       6 df['sex'] = df.apply(lambda row: 1 if row['sex'] == 'Masculino' else 0, axis= 1)
#       7 df['parda'] = df.apply(lambda row: 1 if row['ethnicity'] == 'Parda' else 0, axis= 1)
#
# e:\Python\Python3.12\Lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10030             by_row=by_row,
#   10031             args=args,
# ...

# %%
model = LinearRegression(n_jobs= None, fit_intercept= True, copy_X= True)

x = df[['drugs', 'alcohol', 'tobacco', 'sex', 'age', 'parda', 'branca', 'negra', 'amarela']].to_numpy()
y = df['imc'].to_numpy()
model.fit(x, y)

print(model.score(x, y))

x = sm.add_constant(x)
model = sm.OLS(y, x).fit()

print(model.summary())
# Out:
# 0.026699566610750236
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     18.00
# Date:                Mon, 26 Feb 2024   Prob (F-statistic):           2.53e-05
# Time:                        11:12:10   Log-Likelihood:                -2199.6
# No. Observations:                 658   AIC:                             4403.
# Df Residuals:                     656   BIC:                             4412.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.7017      0.304     97.710      0.000      29.105      30.299
# ...
