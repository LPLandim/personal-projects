# %% [markdown]
# # Aula 1

# %%
import pandas as pd

# %%
dados1 = pd.read_json("E:/Documentos/Aulas/Alura/Python Data Science/datasets/dados_hospedagem.json")
dados1.head(10)
# Out:
#                                          info_moveis
# 0  {'avaliacao_geral': '10.0', 'experiencia_local...
# 1  {'avaliacao_geral': '10.0', 'experiencia_local...
# 2  {'avaliacao_geral': '10.0', 'experiencia_local...
# 3  {'avaliacao_geral': '10.0', 'experiencia_local...
# 4  {'avaliacao_geral': '10.0', 'experiencia_local...
# 5  {'avaliacao_geral': '10.0', 'experiencia_local...
# 6  {'avaliacao_geral': '10.0', 'experiencia_local...
# 7  {'avaliacao_geral': '10.0', 'experiencia_local...
# 8  {'avaliacao_geral': '10.0', 'experiencia_local...
# 9  {'avaliacao_geral': '10.0', 'experiencia_local...

# %%
dados1 = pd.json_normalize(dados1['info_moveis'])
dados1.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 1            10.0                --           10
# 2            10.0                --           11
# 3            10.0                --           12
# 4            10.0                --           14
#
#                                      descricao_local  \
# 0  [This clean and comfortable one bedroom sits r...
# 1  [Welcome to the heart of the 'Ballard Brewery ...
# 2  [New modern house built in 2013.  Spectacular ...
# 3  [Our NW style home is 3200+ sq ft with 3 level...
# 4  [Perfect for groups. 2 bedrooms, full bathroom...
#
#                                 descricao_vizinhanca  \
# 0  [Lower Queen Anne is near the Seattle Center (...
# 1  [--, Capital Hill is the heart of Seattle, bor...
# 2  [Upper Queen Anne is a charming neighborhood f...
# 3  [The Views from our top floor!  Wallingford ha...
# 4  [Safeway grocery store within walking distance...
#
# ...

# %%
# Ler arquivos de dados com read_json;
# Identificar os ajustes necessários para um posterior processamento em um conjunto de dados;
# Normalizar a visualização dos dados com o método json_normalize;
# Entender o problema da precificação inteligente.

# %% [markdown]
# # Aula 2

# %%
colunas = list(dados1.columns)
colunas
# Out:
# ['avaliacao_geral',
#  'experiencia_local',
#  'max_hospedes',
#  'descricao_local',
#  'descricao_vizinhanca',
#  'quantidade_banheiros',
#  'quantidade_quartos',
#  'quantidade_camas',
#  'modelo_cama',
#  'comodidades',
#  'taxa_deposito',
#  'taxa_limpeza',
#  'preco']

# %%
dados1 = dados1.explode(colunas[3:])
dados1
# Out:
#    avaliacao_geral experiencia_local max_hospedes  \
# 0             10.0                --            1
# 0             10.0                --            1
# 0             10.0                --            1
# 0             10.0                --            1
# 0             10.0                --            1
# ..             ...               ...          ...
# 68             nan                --            8
# 68             nan                --            8
# 68             nan                --            8
# 69             nan                --            9
# 69             nan                --            9
#
#                                       descricao_local  \
# 0   This clean and comfortable one bedroom sits ri...
# 0   Our century old Upper Queen Anne house is loca...
# 0   Cozy room in two-bedroom apartment along the l...
# 0   Very lovely and cozy room for one. Convenientl...
# 0   The “Studio at Mibbett Hollow' is in a Beautif...
# ...

# %%
dados1.reset_index(inplace = True,  drop = True)
dados1
# Out:
#      avaliacao_geral experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --            1
# 2               10.0                --            1
# 3               10.0                --            1
# 4               10.0                --            1
# ...              ...               ...          ...
# 3813             nan                --            8
# 3814             nan                --            8
# 3815             nan                --            8
# 3816             nan                --            9
# 3817             nan                --            9
#
#                                         descricao_local  \
# 0     This clean and comfortable one bedroom sits ri...
# 1     Our century old Upper Queen Anne house is loca...
# 2     Cozy room in two-bedroom apartment along the l...
# 3     Very lovely and cozy room for one. Convenientl...
# ...

# %%
dados1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   object
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   object
#  6   quantidade_quartos    3818 non-null   object
#  7   quantidade_camas      3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: object(13)
# memory usage: 387.9+ KB

# %%
import numpy as np

# %%
dados1['max_hospedes'] = dados1['max_hospedes'].astype(np.int64)

# %%
dados1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   object
#  6   quantidade_quartos    3818 non-null   object
#  7   quantidade_camas      3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 387.9+ KB

# %%
col_numericas = ['quantidade_banheiros', 'quantidade_quartos', 'quantidade_camas']

# %%
dados1[col_numericas] = dados1[col_numericas].astype(np.int64)

# %%
dados1['avaliacao_geral'] = dados1["avaliacao_geral"].astype(np.float64)

# %%
dados1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   int64
#  6   quantidade_quartos    3818 non-null   int64
#  7   quantidade_camas      3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 387.9+ KB

# %%
dados1['preco'] = dados1['preco'].apply(lambda x: x.replace('$', '').replace(',', '').strip())

# %%
dados1["preco"] = dados1["preco"].astype(np.float64)

# %%
dados1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   int64
#  6   quantidade_quartos    3818 non-null   int64
#  7   quantidade_camas      3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 387.9+ KB

# %%
dados1[['taxa_deposito', 'taxa_limpeza']] = dados1[['taxa_deposito', 'taxa_limpeza']].applymap(lambda x: x.replace("$", '').replace(',', '').strip())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11044\1740167361.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   dados1[['taxa_deposito', 'taxa_limpeza']] = dados1[['taxa_deposito', 'taxa_limpeza']].applymap(lambda x: x.replace("$", '').replace(',', '').strip())

# %%
dados1[['taxa_deposito', 'taxa_limpeza']] = dados1[['taxa_deposito', 'taxa_limpeza']].astype(np.float64)

# %%
dados1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   int64
#  6   quantidade_quartos    3818 non-null   int64
#  7   quantidade_camas      3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   float64
#  11  taxa_limpeza          3818 non-null   float64
#  12  preco                 3818 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 387.9+ KB

# %%
# Identificar e transformar elementos dentro de listas em uma nova linha do DataFrame com explode;
# Transformar dados textuais em numéricos com o método astype;
# Tratar textos com dados numéricos para serem transformados com apply; e
# Tratar várias colunas elemento a elemento com applymap.

# %% [markdown]
# # Aula 3

# %%
dados1['descricao_local'] = dados1['descricao_local'].str.lower()

# %%
dados1.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %%
dados1['descricao_local'][3169]
# Out:
# "built, run and supported by seattle tech and start up veterans, grokhome's focus is to create a supportive environment for smart people working on interesting projects, start ups and more. this listing is an upper bunk, in a 2-person shared room. *note: this fall, there will be major renovations happening on one kitchen and bathroom at a time. there will always be two other working kitchens and two working bathrooms in the house. we'll work to minimize the impact these renovations have on your stay. **this listing is only available to those working in the tech/science space. live in a hacker house, and immerse yourself in the seattle tech scene. you can expect to be surrounded by smart people solving big problems or working on something fun. we have frequent demo nights, and love when our guests share something they are passionate about. if you're new to the city, our deep ties to the seattle tech scene can help you get involved. expand your network, develop your ideas, and learn so
# ...

# %%
dados1['descricao_local'] = dados1['descricao_local'].str.replace('[^a-z A-Z 0-9 \-\']',' ', regex= True)

# %%
dados1['descricao_local'] = dados1['descricao_local'].str.replace('(?<!\w)-(?!\w)',' ', regex= True)

# %%
dados1['descricao_local'] = dados1['descricao_local'].str.split()
dados1.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %%
dados1['comodidades'] = dados1['comodidades'].str.replace('\{|}|\"', '', regex = True)

# %%
dados1['comodidades'] = dados1['comodidades'].str.split(',')
dados1.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %%
dados1['descricao_vizinhanca'] = dados1['descricao_vizinhanca'].str.lower()

# %%
dados1['descricao_vizinhanca'] = dados1['descricao_vizinhanca'].str.replace('[^a-zA-Z0-9\-\']', ' ', regex=True)
dados1['descricao_vizinhanca'] = dados1['descricao_vizinhanca'].str.replace('(?<!\w)-(?!\w)', '', regex=True)

# %%
# Transformamos o texto em lista, formando o token
dados1['descricao_vizinhanca'] = dados1['descricao_vizinhanca'].str.split()
dados1.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  [lower, queen, anne, is, near, the, seattle, c...                     1
# 1  [upper, queen, anne, is, a, really, pleasant, ...                     1
# 2  [the, convenience, of, being, in, seattle, but...                     1
# ...

# %%
# Manipular elementos textuais em um DataFrame;
# Trabalhar com expressões regulares (regex) para tratar o texto;
# Transformar textos em listas;
# Realizar o processo de tokenização de strings.

# %% [markdown]
# # Aula 4

# %%
import datetime

# criando um objeto datetime com a data e hora atual
agora = datetime.datetime.now()

print("Data e hora atual:", agora)

import datetime
# criando um objeto date com a data de hoje
hoje = datetime.date.today()

print("Data de hoje:", hoje)

import datetime

# criando dois objetos date com datas diferentes
data_1 = datetime.date(2022, 1, 1)
data_2 = datetime.date(2023, 1, 1)

# calculando a diferença entre as duas datas
diferenca = data_2 - data_1

print("Diferença entre as duas datas:", diferenca)
# Out:
# Data e hora atual: 2023-09-21 19:28:50.079621
# Data de hoje: 2023-09-21
# Diferença entre as duas datas: 365 days, 0:00:00

# %%
dt_data = pd.read_json("E:/Documentos/Aulas/Alura/Python Data Science/datasets/moveis_disponiveis.json")
dt_data.head()
# Out:
#     id        data  vaga_disponivel preco
# 0  857  2016-01-04            False  None
# 1  857  2016-01-05            False  None
# 2  857  2016-01-06            False  None
# 3  857  2016-01-07            False  None
# 4  857  2016-01-08            False  None

# %%
dt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               365000 non-null  int64
#  1   data             365000 non-null  object
#  2   vaga_disponivel  365000 non-null  bool
#  3   preco            270547 non-null  object
# dtypes: bool(1), int64(1), object(2)
# memory usage: 11.5+ MB

# %%
dt_data['data'] = pd.to_datetime(dt_data['data'])

# %%
dt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               365000 non-null  int64
#  1   data             365000 non-null  datetime64[ns]
#  2   vaga_disponivel  365000 non-null  bool
#  3   preco            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 11.5+ MB

# %%
dt_data.head()
# Out:
#     id       data  vaga_disponivel preco
# 0  857 2016-01-04            False  None
# 1  857 2016-01-05            False  None
# 2  857 2016-01-06            False  None
# 3  857 2016-01-07            False  None
# 4  857 2016-01-08            False  None

# %%
dt_data['data'].dt.strftime("%Y-%m")
# Out:
# 0         2016-01
# 1         2016-01
# 2         2016-01
# 3         2016-01
# 4         2016-01
#            ...
# 364995    2016-12
# 364996    2016-12
# 364997    2016-12
# 364998    2017-01
# 364999    2017-01
# Name: data, Length: 365000, dtype: object

# %%
subset = dt_data.groupby(dt_data['data'].dt.strftime("%Y-%m"))['vaga_disponivel'].sum()
subset.head()
# Out:
# data
# 2016-01    16543
# 2016-02    20128
# 2016-03    23357
# 2016-04    22597
# 2016-05    23842
# Name: vaga_disponivel, dtype: int64

# %%
import numpy as np

# utilizamos o método fillna para preencher os elementos vazios por '0.0'
# definimos o parâmetro de inplace para True para substituir no DataFrame
dt_data['preco'].fillna('0.0', inplace = True)

# apagamos o $ e as vírgulas com apply lambda
dt_data['preco'] = dt_data['preco'].apply(lambda x: x.replace('$', '').replace(',',''))

# %%
# transformamos os tipos de dados para float64
dt_data['preco'] = dt_data['preco'].astype(np.float64)
dt_data
# Out:
#           id       data  vaga_disponivel  preco
# 0        857 2016-01-04            False    0.0
# 1        857 2016-01-05            False    0.0
# 2        857 2016-01-06            False    0.0
# 3        857 2016-01-07            False    0.0
# 4        857 2016-01-08            False    0.0
# ...      ...        ...              ...    ...
# 364995  3279 2016-12-29             True  140.0
# 364996  3279 2016-12-30             True  140.0
# 364997  3279 2016-12-31             True  140.0
# 364998  3279 2017-01-01             True  140.0
# 364999  3279 2017-01-02            False    0.0
#
# [365000 rows x 4 columns]

# %% [markdown]
# # Desafios

# %%
# Desafio 1

dados = pd.read_json("E:/Documentos/Aulas/Alura/Python Data Science/datasets/dados_vendas_clientes.json")

dados = dados = pd.json_normalize(dados['dados_vendas'])
dados
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %%
colunas = list(dados.columns)
colunas
# Out:
# ['Data de venda', 'Cliente', 'Valor da compra']

# %%
dados = dados.explode(colunas[1:])
dados.reset_index(drop = True, inplace = True)
dados.head()
# Out:
#   Data de venda             Cliente Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 1    06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 2    06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 3    06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 4    07/06/2022  Isabely JOanes 738       R$ 825,31

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     object
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     object
# dtypes: object(3)
# memory usage: 612.0+ bytes

# %%
dados['Valor da compra'].head()
# Out:
# 0     R$ 836,5
# 1    R$ 573,33
# 2     R$ 392,8
# 3    R$ 512,34
# 4    R$ 825,31
# Name: Valor da compra, dtype: object

# %%
import numpy as np

dados['Valor da compra'] = dados['Valor da compra'].apply(lambda x: x.replace("R$", "").replace(",", ".").strip())

dados['Valor da compra'] = dados['Valor da compra'].astype(np.float64)

# %%
dados.info()
dados.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     object
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 612.0+ bytes
#   Data de venda             Cliente  Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321           836.50
# 1    06/06/2022  DieGO ARMANDIU 210           573.33
# 2    06/06/2022  DieGO ARMANDIU 210           392.80
# 3    06/06/2022  DieGO ARMANDIU 210           512.34
# 4    07/06/2022  Isabely JOanes 738           825.31

# %%
# Transformar os textos de Cliente para texto em minúsculo
dados['Cliente'] = dados['Cliente'].str.lower()
dados.head()
# Out:
#   Data de venda             Cliente  Valor da compra
# 0    06/06/2022     @ana _lucia 321           836.50
# 1    06/06/2022  diego armandiu 210           573.33
# 2    06/06/2022  diego armandiu 210           392.80
# 3    06/06/2022  diego armandiu 210           512.34
# 4    07/06/2022  isabely joanes 738           825.31

# %%
# Opção de substituição - necessário verificar o resultado da substituição
# O regex não seleciona todas as letras de a-z e espaços em branco ' '
# Tudo que satisfaz o regex é apagado
dados['Cliente'].str.replace('[^a-z ]', '', regex=True)
# Out:
# 0          ana lucia
# 1     diego armandiu
# 2     diego armandiu
# 3     diego armandiu
# 4     isabely joanes
# 5     isabely joanes
# 6     isabely joanes
# 7     isabely joanes
# 8     isabely joanes
# 9        joo gabriel
# 10    julya meireles
# 11    julya meireles
# 12    julya meireles
# 13       maria julia
# 14       maria julia
# 15       maria julia
# 16       maria julia
# 17       pedro pasco
# 18      paulo castro
# 19     thiago fritzz
# Name: Cliente, dtype: object

# %%
# Realizar a substituição dos dados na coluna textual
dados['Cliente'] = dados['Cliente'].str.replace('[^a-z ]', '', regex=True).str.strip()
dados.head()
# Out:
#   Data de venda         Cliente  Valor da compra
# 0    06/06/2022       ana lucia           836.50
# 1    06/06/2022  diego armandiu           573.33
# 2    06/06/2022  diego armandiu           392.80
# 3    06/06/2022  diego armandiu           512.34
# 4    07/06/2022  isabely joanes           825.31

# %%
# Transformar para o tipo datetime definindo o formato de data como DD/MM/AAAA ('%d/%m/%Y')
dados['Data de venda'] = pd.to_datetime(dados['Data de venda'], format='%d/%m/%Y')
# Visualizar o resultado
dados
# Out:
#    Data de venda         Cliente  Valor da compra
# 0     2022-06-06       ana lucia           836.50
# 1     2022-06-06  diego armandiu           573.33
# 2     2022-06-06  diego armandiu           392.80
# 3     2022-06-06  diego armandiu           512.34
# 4     2022-06-07  isabely joanes           825.31
# 5     2022-06-07  isabely joanes           168.07
# 6     2022-06-07  isabely joanes           339.18
# 7     2022-06-07  isabely joanes           314.69
# 8     2022-06-08  isabely joanes           682.05
# 9     2022-06-08     joo gabriel           386.34
# 10    2022-06-08  julya meireles           622.65
# 11    2022-06-08  julya meireles           630.79
# 12    2022-06-09  julya meireles           390.30
# 13    2022-06-09     maria julia           759.16
# 14    2022-06-09     maria julia           334.47
# 15    2022-06-09     maria julia           678.78
# 16    2022-06-10     maria julia           314.24
# 17    2022-06-10     pedro pasco           311.15
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     datetime64[ns]
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 612.0+ bytes

# %%
# Calcular o total arrecadado em compras por cada cliente
total_compras = dados.groupby(['Cliente'])['Valor da compra'].sum()
total_compras
# Out:
# Cliente
# ana lucia          836.50
# diego armandiu    1478.47
# isabely joanes    2329.30
# joo gabriel        386.34
# julya meireles    1643.74
# maria julia       2086.65
# paulo castro       899.16
# pedro pasco        311.15
# thiago fritzz      885.24
# Name: Valor da compra, dtype: float64

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %%
# Desafio 2

dados = pd.read_json("E:/Documentos/Aulas/Alura/Python Data Science/datasets/dados_locacao_imoveis.json")

dados = dados = pd.json_normalize(dados['dados_locacao'])
dados.head()
# Out:
#       apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0  A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1  A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2  B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3  B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4  C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
#
#                       valor_aluguel
# 0  [$ 1000,0 reais, $ 2500,0 reais]
# 1  [$ 1100,0 reais, $ 2600,0 reais]
# 2  [$ 1200,0 reais, $ 2700,0 reais]
# 3  [$ 1300,0 reais, $ 2800,0 reais]
# 4  [$ 1400,0 reais, $ 2900,0 reais]

# %%
colunas = list(dados.columns)
colunas
# Out:
# ['apartamento',
#  'datas_combinadas_pagamento',
#  'datas_de_pagamento',
#  'valor_aluguel']

# %%
dados = dados.explode(colunas[1:])
dados.reset_index(drop=True,inplace=True)
dados.head()
# Out:
#       apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0  A101 (blocoAP)                 01/06/2022         05/06/2022
# 1  A101 (blocoAP)                 01/07/2022         03/07/2022
# 2  A102 (blocoAP)                 02/06/2022         02/06/2022
# 3  A102 (blocoAP)                 02/07/2022         06/07/2022
# 4  B201 (blocoAP)                 03/06/2022         07/06/2022
#
#     valor_aluguel
# 0  $ 1000,0 reais
# 1  $ 2500,0 reais
# 2  $ 1100,0 reais
# 3  $ 2600,0 reais
# 4  $ 1200,0 reais

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
dados['valor_aluguel'].head()
# Out:
# 0    $ 1000,0 reais
# 1    $ 2500,0 reais
# 2    $ 1100,0 reais
# 3    $ 2600,0 reais
# 4    $ 1200,0 reais
# Name: valor_aluguel, dtype: object

# %%
import numpy as np

dados['valor_aluguel'] = dados['valor_aluguel'].apply(lambda x: x.replace('$ ', '').replace(' reais', '').replace(',','.').strip())
dados['valor_aluguel'] = dados['valor_aluguel'].astype(np.float64)

# %%
# Opção de substituição - necessário verificar o resultado da substituição
# Foi necessário adicionar a barra '\' para ser considerados os parênteses como caracteres literais
dados['apartamento'].str.replace(' \(blocoAP\)', '')
# Out:
# 0     A101 (blocoAP)
# 1     A101 (blocoAP)
# 2     A102 (blocoAP)
# 3     A102 (blocoAP)
# 4     B201 (blocoAP)
# 5     B201 (blocoAP)
# 6     B202 (blocoAP)
# 7     B202 (blocoAP)
# 8     C301 (blocoAP)
# 9     C301 (blocoAP)
# 10    C302 (blocoAP)
# 11    C302 (blocoAP)
# 12    D401 (blocoAP)
# 13    D401 (blocoAP)
# 14    D402 (blocoAP)
# 15    D402 (blocoAP)
# 16    E501 (blocoAP)
# 17    E501 (blocoAP)
# 18    E502 (blocoAP)
# 19    E502 (blocoAP)
# 20    F601 (blocoAP)
# 21    F601 (blocoAP)
# 22    F602 (blocoAP)
# 23    F602 (blocoAP)
# 24    G701 (blocoAP)
# 25    G701 (blocoAP)
# 26    G702 (blocoAP)
# 27    G702 (blocoAP)
# 28    H801 (blocoAP)
# 29    H801 (blocoAP)
# Name: apartamento, dtype: object

# %%
# Realizar a substituição dos dados na coluna textual
dados['apartamento'] = dados['apartamento'].str.replace(' \(blocoAP\)', '')
dados.head()
# Out:
#       apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0  A101 (blocoAP)                 01/06/2022         05/06/2022         1000.0
# 1  A101 (blocoAP)                 01/07/2022         03/07/2022         2500.0
# 2  A102 (blocoAP)                 02/06/2022         02/06/2022         1100.0
# 3  A102 (blocoAP)                 02/07/2022         06/07/2022         2600.0
# 4  B201 (blocoAP)                 03/06/2022         07/06/2022         1200.0

# %%
# Transformar para o tipo datetime definindo o formato de data como DD/MM/AAAA ('%d/%m/%Y')
dados['datas_combinadas_pagamento'] = pd.to_datetime(dados['datas_combinadas_pagamento'], format='%d/%m/%Y')
dados['datas_de_pagamento'] = pd.to_datetime(dados['datas_de_pagamento'], format='%d/%m/%Y')

dados.head()
# Out:
#       apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0  A101 (blocoAP)                 2022-06-01         2022-06-05
# 1  A101 (blocoAP)                 2022-07-01         2022-07-03
# 2  A102 (blocoAP)                 2022-06-02         2022-06-02
# 3  A102 (blocoAP)                 2022-07-02         2022-07-06
# 4  B201 (blocoAP)                 2022-06-03         2022-06-07
#
#    valor_aluguel  atraso
# 0         1000.0       4
# 1         2500.0       2
# 2         1100.0       0
# 3         2600.0       4
# 4         1200.0       4

# %%
# Para contribuir na solução do contexto é possível calcular a diferença de dias
# entre a data combinada e a data de pagamento com dt.days
dados['atraso'] = (dados['datas_de_pagamento'] - dados['datas_combinadas_pagamento']).dt.days

dados.head()
# Out:
#       apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0  A101 (blocoAP)                 2022-06-01         2022-06-05
# 1  A101 (blocoAP)                 2022-07-01         2022-07-03
# 2  A102 (blocoAP)                 2022-06-02         2022-06-02
# 3  A102 (blocoAP)                 2022-07-02         2022-07-06
# 4  B201 (blocoAP)                 2022-06-03         2022-06-07
#
#    valor_aluguel  atraso
# 0         1000.0       4
# 1         2500.0       2
# 2         1100.0       0
# 3         2600.0       4
# 4         1200.0       4

# %%
# Calcular a média de tempo de atraso por apartamentos
media_atraso = dados.groupby(['apartamento'])['atraso'].mean()

# Visualizar o resultado
media_atraso
# Out:
# apartamento
# A101 (blocoAP)    3.0
# A102 (blocoAP)    2.0
# B201 (blocoAP)    2.0
# B202 (blocoAP)    2.0
# C301 (blocoAP)    4.5
# C302 (blocoAP)    4.0
# D401 (blocoAP)    1.0
# D402 (blocoAP)    4.0
# E501 (blocoAP)    0.5
# E502 (blocoAP)    4.0
# F601 (blocoAP)    4.0
# F602 (blocoAP)    1.5
# G701 (blocoAP)    6.5
# G702 (blocoAP)    2.0
# H801 (blocoAP)    2.0
# Name: atraso, dtype: float64
